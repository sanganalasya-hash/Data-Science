# %% [markdown]
# <a href="https://colab.research.google.com/github/sanganalasya-hash/Data-Science/blob/main/Copy_of_Unit3ExercisesSF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install preliz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 8.0 MB/s eta 0:00:00
# ...

# %%
import preliz as pz

# %% [markdown]
# # Unit 3 Exercises: Delightfully Diverse Distirbutions
#
# Use these exercises as a chance to explore the probability distributions (dists) from the pymc and preliz libraries. [Moments](https://en.wikipedia.org/wiki/Moment_(mathematics)), the main subject of these exercises, are a great way to describe dists, but there's another  way: [maximum entropy](https://en.wikipedia.org/wiki/Maximum_entropy_probability_distribution#Other_examples), which, although important, we will not cover in detail.
#
# Here's what we'll cover in this Unit's exercises:
# - The first four moments: mean, variance, skew, and kurtosis, as well as the support.
# - Single variable continuous distributions.
# - Single variable discrete distriutions
#
#
# Why do we need to know this stuff? Two reasons:
# - Probability distributions are required to set priors and likelihoods in pymc.
# - Randomness and uncertainty are not well defined mathematically, but probability and probability distributions are.
#
# With that in mind, think of these exercises as an oppurtunity to explore the ways we can be uncertain, or the ways things can be random.

# %% [markdown]
# ## The First Four Moments: Mean, Variance, Skew, and Kurtosis
#
# When we talk about a probablity dist, we often care about at four things:
# - The expected value, or where a distribution is centered (mean)
# - The amount of variation from that centered value (variation)
# - Whether or not our distribution favors, leans towards, or skews towards certain values. (skew)
# - How often to expect unusually high or low values. (kurtosis)

# %% [markdown]
# ### Playing with Beta

# %% [markdown]
# **Task1**:
#
# Plot a [preliZ Beta distribution](https://preliz.readthedocs.io/en/latest/api_reference.html#preliz.distributions.beta.Beta) with $α=1$ and $β=1$.

# %%
from preliz import Beta, style
style.use('preliz-doc')
alphas = [1]
betas = [1]
for alpha, beta in zip(alphas, betas):
    ax = Beta(alpha, beta).plot_pdf()
ax.set_ylim(0, 5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# **Task2**:
#
# Find the mean, variance, skew, and kurtosis of a $Beta(1,1)$ distribution. This is the same as asking for the first four moments of a $Beta(1,1)$ distribution.
#
# *Hint*: preliZ has built in function that does this for you.

# %%
pz.Beta(alpha=1,beta=1).moments()
# Out:
# [np.float64(0.5), np.float64(0.08333333333333333), array(0.), np.float64(-1.2)]

# %% [markdown]
# **Task3**:
#
# Plot the following distributions on seperate graphs: $Beta(1,1)$, $Beta(0.9,0.9)$, $Beta(2,1)$, $Beta(1,2)$, $Beta(7,11)$, $Beta(96,42)$, $Beta(5,5)$, $Beta(500,500)$, $Beta(0.8,0.9)$.
#
# Then, determine which of those distribtuions has:
# - the largest/smallest mean
# - the largest/smallest variance
# - the largest/smallest skew
# - the largest/smallest kurtosis
#
# and show the code you used to find that information.

# %%
from preliz import Beta, style
style.use('preliz-doc')
alphas = [1,0.9,2,1,7,96,5,500,.8]
betas = [1, 0.9,1,2,11,42,5,500,0.9]
for alpha, beta in zip(alphas, betas):
    ax = Beta(alpha, beta).plot_pdf()
ax.set_ylim(0, 5)
# Out:
# (0.0, 5.0)

# %%
pz.Beta(alpha=1,beta=1).moments()
# Out:
# [np.float64(0.5), np.float64(0.08333333333333333), array(0.), np.float64(-1.2)]

# %%
pz.Beta(alpha=.9,beta=.9).moments()
# Out:
# [np.float64(0.5),
#  np.float64(0.0892857142857143),
#  array(0.),
#  np.float64(-1.2500000000000002)]

# %%
pz.Beta(alpha=2,beta=1).moments()
# Out:
# [np.float64(0.6666666666666666),
#  np.float64(0.05555555555555555),
#  np.float64(-0.565685424949238),
#  np.float64(-0.6)]

# %%
pz.Beta(alpha=1,beta=2).moments()
# Out:
# [np.float64(0.3333333333333333),
#  np.float64(0.05555555555555555),
#  np.float64(0.565685424949238),
#  np.float64(-0.6)]

# %%
pz.Beta(alpha=7,beta=11).moments()
# Out:
# [np.float64(0.3888888888888889),
#  np.float64(0.012508122157244964),
#  np.float64(0.1986970545340808),
#  np.float64(-0.22931354359925787)]

# %%
pz.Beta(alpha=96,beta=42).moments()
# Out:
# [np.float64(0.6956521739130435),
#  np.float64(0.0015231670995906488),
#  np.float64(-0.14323292412687752),
#  np.float64(-0.011997937472861485)]

# %%
pz.Beta(alpha=5,beta=5).moments()
# Out:
# [np.float64(0.5),
#  np.float64(0.022727272727272728),
#  array(0.),
#  np.float64(-0.46153846153846156)]

# %%
pz.Beta(alpha=500,beta=500).moments()
# Out:
# [np.float64(0.5),
#  np.float64(0.00024975024975024975),
#  array(0.),
#  np.float64(-0.005982053838484547)]

# %%
pz.Beta(alpha=.8,beta=.9).moments()
# Out:
# [np.float64(0.47058823529411764),
#  np.float64(0.09227220299884659),
#  np.float64(0.1046752255731734),
#  np.float64(-1.263657274295572)]

# %% [markdown]
# Mean:
#
# Largest Mean:  Beta(96,42)  (0.69565...)
# Smallest Mean:  Beta(1,2)  (0.33333...)
#
# Variance:
#
# Largest Variance:  Beta(0.8,0.9)  (0.09227...)
# Smallest Variance:  Beta(500,500)  (0.0002497...)
#
# Skew:
#
# Largest Skew:  Beta(1,2)  (0.56568...)
# Smallest Skew:  Beta(2,1)  (-0.56568...)
#
# Kurtosis:
#
# Largest Kurtosis:  Beta(96,42)  (-0.01199...)
# Smallest Kurtosis:  Beta(0.8,0.9)  (-1.26365...)

# %% [markdown]
# ###Playing with other Continuous Distributions
#
# For the remaining tasks, make sure to continue to use the [preliZ documentation](https://preliz.readthedocs.io/en/latest/api_reference.html).
#
# The [wikipedia pages for each of the probability distributions](https://en.wikipedia.org/wiki/List_of_probability_distributions) are also great resources.
#
# [Wolfram Alpha](https://www.wolframalpha.com/examples/mathematics/probability/probability-distributions) is another great resource as well.

# %% [markdown]
# **Task4**:
#
# Plot the pdfs of each of the following distributions on the same graph: $Normal(μ=0,σ=1)$, $StudentT(ν=5,μ=0,σ=1)$
#
# Then, plot these on the same graph: $Exponential(λ=1/2)$, $Gamma(α=2,β=1)$, $HalfStudentT(ν=5,σ1)$
#
# For the t distribution and half t, use
#
# ```
# support=(-4,4)
# ```
# and
# ```
# support=(0,4)
# ```
# respectively, inside the plot_pdf function.

# %%
from preliz import Normal, style
style.use('preliz-doc')
mus = [0.]
sigmas = [1]
for mu, sigma in zip(mus, sigmas):
    Normal(mu, sigma).plot_pdf()
    from preliz import StudentT, style
style.use('preliz-doc')
nus = [5]
mus = [0.]
sigmas = [1.]
for nu, mu, sigma in zip(nus, mus, sigmas):
    StudentT(nu, mu, sigma).plot_pdf(support=(-4,4))

# %%
from preliz import Exponential, style
style.use('preliz-doc')
for lam in [0.5]:
    Exponential(lam).plot_pdf(support=(0,5))
    from preliz import Gamma, style
style.use('preliz-doc')
alphas = [2]
betas = [1]
for alpha, beta in zip(alphas, betas):
    Gamma(alpha, beta).plot_pdf()
    from preliz import HalfStudentT, style
style.use('preliz-doc')
sigmas = [1]
nus = [5]
for sigma, nu in zip(sigmas, nus):
    HalfStudentT(nu, sigma).plot_pdf(support=(0,4))

# %% [markdown]
# **Task5:**
#
# Find the first four moments of the the distributions from Task4. Then,
#
# Determine which of those five dsitributions has the largest and smallest: mean, variance, skew, and kurtosis. (Ignore skew and kurtosis for the Half StudentT)
#
# Those distributions are repeated here for conveniencce: $Normal(μ=0,σ=1)$, $StudentT(ν=5,μ=0,σ=1)$,  $Exponential(λ=1/2)$, $Gamma(α=2,β=1)$, $HalfStudentT(ν=5,σ=1)$

# %%
pz.Normal(mu=0, sigma=1).moments()
# Out:
# [np.float64(0.0), np.float64(1.0), 0, 0]

# %%
pz.StudentT(nu=5, mu=0, sigma=1).moments()
# Out:
# [np.float64(0.0), np.float64(1.6666666666666667), 0, np.float64(6.0)]

# %%
pz.Exponential(lam=.5).moments()
# Out:
# [np.float64(2.0), np.float64(4.0), 2, 6]

# %%
pz.Gamma(alpha=2,beta=1).moments()
# Out:
# [np.float64(2.0),
#  np.float64(2.0),
#  np.float64(1.414213562373095),
#  np.float64(3.0)]

# %%
pz.HalfStudentT(nu=5, sigma=1).moments()
# Out:
# [np.float64(0.9490167245562356),
#  np.float64(0.7660339231792207),
#  NotImplemented,
#  NotImplemented]

# %% [markdown]
# Mean:
#
# Largest Mean: Exponential( λ=1/2 ) and Gamma( α=2,β=1 ) (both have a mean of 2.0)
# Smallest Mean: Normal( μ=0,σ=1 ) and StudentT( ν=5,μ=0,σ=1 ) (both have a mean of 0.0)
#
# Variance:
#
# Largest Variance: Exponential( λ=1/2 ) (4.0)
# Smallest Variance: HalfStudentT( ν=5,σ=1 ) (0.7660...)
#
# Skew:
#
# Largest Skew: Exponential( λ=1/2 ) (2.0)
# Smallest Skew: Normal( μ=0,σ=1 ) and StudentT( ν=5,μ=0,σ=1 ) (both have a skew of 0)
#
# Kurtosis:
#
# Largest Kurtosis: Exponential( λ=1/2 ) and StudentT( ν=5,μ=0,σ=1 ) (both have a kurtosis of 6.0)
# Smallest Kurtosis: Normal( μ=0,σ=1 ) (0)

# %% [markdown]
# **Task6**:
#
# What x values do the Exponenital, Gamma, HalfSutdentT, and HalfNormal functions support? Why plot them on the same graph?
#
# What x values do the Normal and T distribution support? Why plot them on the same graph?
#
# What x values does the Beta distribution support?

# %% [markdown]
# Exponential, Gamma, HalfStudentY and HalfNormal support x-values from 0 to infinity. If you plot them on the same graph, since them have the same non-negative domain it is easy to compare.
#
# Normal and T distribution supports x-values from negative infinity to infinity. If you plot them on the same graph, it highlights their similarities and differences better.
#
# The Beta distribution plots x-values 0 to 1.

# %% [markdown]
# **Task7**:
#
# Can a distribution with support $[0,∞]$ have negative (or left) skew? If so, plot that specific distribution.

# %% [markdown]
# No.

# %% [markdown]
# **Task8**:
#
# Name a distribution that supports the real numbers with variance equal to 1, 0 skew, and 0 kurtosis.

# %% [markdown]
# Normal Distribution

# %% [markdown]
# **Task9**:
#
# Name a distribution with support $(-∞,∞)$ and that has negative skew.

# %% [markdown]
# T distribution

# %% [markdown]
# **Optional Task**:
#
# What are the maximum entropy conditions for the normal and gamma distributions?

# %% [markdown]
# ###Playing with Discrete Distributions

# %% [markdown]
# **Task9**:
#
# Plot the pdfs (techincally the pmfs) of the following distributions: $Bernoulli(p=0.7)$, $Binomial(n=10,p=0.7)$, $Poisson(μ=7)$, $Geometric(p=0.7)$, $HyperGeometric(N=50,k=35,n=15)$, $Categorical(p=[0.05,0.3,0.05,0.1,0.2,0.4])$
#
# Additionally, compute the first four moments for all those distributions--except the Categorical distribution.

# %%
from preliz import Bernoulli, style
style.use('preliz-doc')
for p in [.7]:
    Bernoulli(p).plot_pdf()

from preliz import Binomial, style
style.use('preliz-doc')
ns = [10]
ps = [0.7]
for n, p in zip(ns, ps):
    Binomial(n, p).plot_pdf()

from preliz import Poisson, style
style.use('preliz-doc')
for mu in [7]:
    Poisson(mu).plot_pdf()

from preliz import Geometric, style
style.use('preliz-doc')
for p in [.7]:
    Geometric(p).plot_pdf(support=(1,10))

from preliz import HyperGeometric, style
style.use('preliz-doc')
N = 50
k = 35
for n in [15]:
    HyperGeometric(N, k, n).plot_pdf(support=(1,15))

from preliz import Categorical, style
style.use('preliz-doc')
ps = [[0.05,0.3,0.05,0.1,0.2,0.4]]
for p in ps:
    Categorical(p).plot_pdf()

# %%
pz.Binomial(n=10, p=.7).moments()
# Out:
# [np.float64(0.7),
#  np.float64(0.21000000000000002),
#  np.float64(-0.8728715609439692),
#  np.float64(-1.238095238095238)]

# %%
pz.Bernoulli(p=.7).moments()
# Out:
# [np.float64(0.7),
#  np.float64(0.21000000000000002),
#  np.float64(-0.8728715609439692),
#  np.float64(-1.238095238095238)]

# %%
pz.Poisson(mu=7).moments()
# Out:
# [np.float64(7.0),
#  np.float64(7.0),
#  np.float64(0.3779644730092272),
#  np.float64(0.14285714285714285)]

# %%
pz.Geometric(p=.7).moments()
# Out:
# [np.float64(1.4285714285714286),
#  np.float64(0.6122448979591838),
#  np.float64(2.3734644158557194),
#  np.float64(7.633333333333333)]

# %%
pz.HyperGeometric(N=50, k=35, n=15).moments()
# Out:
# [np.float64(10.5),
#  np.float64(2.25),
#  np.float64(-0.1111111111111111),
#  np.float64(-0.08983451536643026)]

# %% [markdown]
# **Task10**:
#
# Describe what processes "generate" each of the previous discrete distributions models. Also report their support.
#
# Here's a spicier way to phrase the question: describe these distributions' maximum entropy conditions in english.
#
# Hint: Make sure to read any of the: preliZ documentation, relevant wikipedia articles, or wolfram alpha.

# %% [markdown]
# Bernoulli: it is a random variable which takes the value 1 with probability
#  and the value 0 with probability. Support (0,1)
#  The Beta-Binomial distribution is a discrete probability distribution derived from the Binomial distribution, with its probability of success in each trial governed by a Beta distribution. This distribution is characterized by three parameters. Support is {0,1,..n}
#  The Binomial distribution is a discrete probability distribution that describes the number of successes in a fixed number
#  of independent Bernoulli trials (yes/no experiments), each with the same probability of success. Support is {0,1,...n}
#  The Categorical distribution is the most general discrete distribution and is parameterized by a vector where each element specifies the probabilities of each possible outcome. Support is {0,1,.. p-1}
#  Univariate, Discrete, Bounded
#
# The Discrete Uniform distribution is a probability distribution where each integer value between lower and upper (inclusive) has the same probability. This distribution is characterized by two parameters: lower and upper, defining the range of integers. Support is {lower, lower+1, upper}
#
# The Discrete Weibull distribution is a discrete probability distribution used to model the number of trials until an event occurs. It is an analog of the continuous Weibull distribution, adapted for discrete settings. The distribution has two shape parameter.
#
# The Geometric distribution is a discrete probability distribution used to model the number of Bernoulli trials required to achieve the first success. The distribution has a single parameter. Support is x = N
#
# The Hypergeometric distribution is a discrete probability distribution used to model the number of successes in a sequence of draws taken without replacement.
#
# The NegativeBinomial distribution describes a Poisson random variable whose rate parameter is Gamma distributed. It is commonly used as an alternative to the Poisson distribution when the variance is greater than the mean (overdispersed data). x= N
#
# The Poisson distribution is a discrete probability distribution that expresses the probability of a given number of events occurring in a fixed interval of time (or space) if these events occur with a known constant mean rate and independently of the time since the last event. X= N
#
# The Zero-Inflated Binomial (ZIB) distribution is a discrete probability distribution used to model count data characterized by an excess of zeros. It combines two components: a standard Binomial distribution and an additional mechanism that increases the probability of observing zero outcomes. X=N
#
# The Zero-Inflated Negative Binomial (ZINB) distribution is a discrete probability distribution used to model count data characterized by an excess of zeros. It combines two components: a NegativeBinomial component, which describe count values and a zero-inflation component, which accounts for the extra zeros. X=N
#
# The Zero-Inflated Poisson (ZIP) distribution is a discrete probability distribution used to model count data characterized by an excess of zeros. It combines two components: a standard Poisson distribution and an additional mechanism that increases the probability of observing zero outcomes.X = N
